# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import json
import re
import time

DELAY = 1  # seconds
BASE_URL = 'https://store.playstation.com'
LIST_BASE_URL = f'{BASE_URL}/en-us/pages/browse'
API_HASH = '16b0b76dac848b6e33ed088a5a3aedb738e51c9481c6a6eb6d6c1c1991ea1f39'
headers={"X-Psn-Store-Locale-Override":"en-US"}


session = requests.Session()

# %%
def ps_digital_scrape(pages=None):
    page = 1

    game_list = []

    # Loop through pages
    while True:
        if (pages is not None) & (page > pages):
            break

        # Retrieve list page
        response = session.get(f'{LIST_BASE_URL}/{page}')
        soup = BeautifulSoup(response.text, 'html.parser')

        # There is no clear way to know when we've arrived at the end.
        # I've found that the "All Games" header does not appear when
        # there are no more results.
        if len(soup.find_all("h1", string="All Games")) == 0:
            break

        # Get games on page
        games = soup.select('ul.psw-grid-list li')

        for game in games:
            data = {}
            path = game.select('div a')[0]['href']

            id_search = re.search('(\d*)$', path, re.IGNORECASE)
            if id_search:
                id = id_search.group(1)
            else:
                id = None

            data['concept_id'] = id
            data['url'] = f'{BASE_URL}/{path}'
            data['img'] = game.select('img.psw-l-fit-cover')[0]['src']

            print(f'id: {id}')
            print(f'url: {data["url"]}\n')

            data = scrape_game_page(data)
            data = scrape_game_api(data)
            game_list.append(data)

            time.sleep(DELAY)

        page = page + 1

    return game_list

def scrape_game_page(data):
    response = session.get(data['url'], headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    name = soup.select('h1[data-qa="mfe-game-title#name"]')
    name = name[0].text if len(name) > 0 else None
    rating = soup.select('img[data-qa="mfe-content-rating#ratingImage#image-no-js"]')
    rating = rating[0]['alt'] if len(rating) > 0 else None

    notice0 = soup.select('span[data-qa="mfe-compatibility-notices#notices#notice0#compatText"]')
    notice0 = notice0[0].text if len(notice0) > 0 else None
    notice1 = soup.select('span[data-qa="mfe-compatibility-notices#notices#notice1#compatText"]')
    notice1 = notice1[0].text if len(notice1) > 0 else None
    notice2 = soup.select('span[data-qa="mfe-compatibility-notices#notices#notice2#compatText"]')
    notice2 = notice2[0].text if len(notice2) > 0 else None
    notice3 = soup.select('span[data-qa="mfe-compatibility-notices#notices#notice3#compatText"]')
    notice3 = notice3[0].text if len(notice3) > 0 else None
    notice4 = soup.select('span[data-qa="mfe-compatibility-notices#notices#notice4#compatText"]')
    notice4 = notice4[0].text if len(notice4) > 0 else None
    notice5 = soup.select('span[data-qa="mfe-compatibility-notices#notices#notice5#compatText"]')
    notice5 = notice5[0].text if len(notice5) > 0 else None

    description = soup.select('p[data-qa="mfe-game-overview#description"]')
    description = description[0].text if len(description) > 0 else None

    platform =  soup.select('dd[data-qa="gameInfo#releaseInformation#platform-value"]')
    platform = platform[0].text if len(platform) > 0 else None
    release = soup.select('dd[data-qa="gameInfo#releaseInformation#releaseDate-value"]')
    release = release[0].text if len(release) > 0 else None
    publisher = soup.select('dd[data-qa="gameInfo#releaseInformation#publisher-value"]')
    publisher = publisher[0].text if len(publisher) > 0 else None
    genre = soup.select('dd[data-qa="gameInfo#releaseInformation#genre-value"] span')
    genre = genre[0].text if len(genre) > 0 else None
    voice_lang = soup.select('dd[data-qa="gameInfo#releaseInformation#voice-value"]')
    voice_lang = voice_lang[0].text if len(voice_lang) > 0 else None
    screen_lang = soup.select('dd[data-qa="gameInfo#releaseInformation#subtitles-value"]')
    screen_lang = screen_lang[0].text if len(screen_lang) > 0 else None

    data['name'] = name
    data['rating'] = rating
    data['notice0'] = notice0
    data['notice1'] = notice1
    data['notice2'] = notice2
    data['notice3'] = notice3
    data['notice4'] = notice4
    data['notice5'] = notice5
    data['description'] = description
    data['platform'] = platform
    data['release'] = release
    data['publisher'] = publisher
    data['genre'] = genre
    data['voice_lang'] = voice_lang
    data['screen_lang'] = screen_lang

    return data

def scrape_game_api(data):
    d = {}
    concept_id = data['concept_id']

    api_url = f'https://web.np.playstation.com/api/graphql/v1//op?operationName=queryRetrieveTelemetryDataPDPConcept&variables={{"conceptId":"{concept_id}","productId":null}}&extensions={{"persistedQuery":{{"version":1,"sha256Hash":"{API_HASH}"}}}}'
    response = session.get(api_url, headers=headers)
    j = json.loads(response.text)

    product = j['data']['conceptRetrieve']['defaultProduct']
    data['c_name'] = j['data']['conceptRetrieve']['name']
    data['c_rating'] = product['contentRating']['name']
    data['c_id'] = product['id']
    data['c_genres'] = list(map(lambda a: a['value'], product['localizedGenres']))
    data['c_default_prod_name'] = product['name']
    data['c_np_title_id'] = product['npTitleId']
    data['c_sku_id'] = product['skus'][0]['id']
    data['c_display_price'] = product['skus'][0]['displayPrice']
    data['c_price'] = product['skus'][0]['price']

    main_cta = list(filter(lambda a: a['price']['serviceBranding'][0] == 'NONE', product['webctas']))
    if len(main_cta) > 0:
        data['c_discounted_price'] = main_cta[0]['price']['discountedPrice']
    else:
        data['c_discounted_price'] = None

    return data

# %%
# Tests

# DRAGON BALL XENOVERSE 2 - https://store.playstation.com/en-us/concept/217012
# ELDEN RING PS4 & PS5 - https://store.playstation.com/en-us/concept/10000333
# Fortnite - https://store.playstation.com//en-us/concept/228748
# Dragon's Dogma: Dark Arisen - https://store.playstation.com//en-us/concept/223963

# data = {
#     'concept_id': '217012',
#     'url': 'https://store.playstation.com/en-us/concept/217012'
# }
# data = scrape_game_page(data)
# data = scrape_game_api(data)
# data

data = ps_digital_scrape(pages=2)
# Out:
# id: 228748
# url: https://store.playstation.com//en-us/concept/228748
#
# id: 10001130
# url: https://store.playstation.com//en-us/concept/10001130
#
# id: 10004836
# url: https://store.playstation.com//en-us/concept/10004836
#
# id: 10002100
# url: https://store.playstation.com//en-us/concept/10002100
#
# id: 231761
# url: https://store.playstation.com//en-us/concept/231761
#
# id: 10002456
# url: https://store.playstation.com//en-us/concept/10002456
#
# id: 201930
# url: https://store.playstation.com//en-us/concept/201930
#
# id: 10004336
# url: https://store.playstation.com//en-us/concept/10004336
#
# id: 10005744
# url: https://store.playstation.com//en-us/concept/10005744
#
# id: 232352
# url: https://store.playstation.com//en-us/concept/232352
#
# id: 10001615
# url: https://store.playstation.com//en-us/concept/10001615
#
# id: 10000896
# url: https://store.playstation.com//en-us/concept/10000896
#
# id: 10003900
# url: https://store.playstation.com//en-us/concept/10003900
#
# id: 212779
# url: https://store.playstation.com//en-us/concept/212779
#
# id: 10006008
# url: https://store.playstation.com//en-us/concept/10006008
#
# id: 216627
# url: https://store.playstation.com//en-us/concept/216627
#
# id: 221852
# url: https://store.playstation.com//en-us/concept/221852
#
# id: 232447
# url: https://store.playstation.com//en-us/concept/232447
#
# id: 203897
# url: https://store.playstation.com//en-us/concept/203897
#
# id: 203715
# url: https://store.playstation.com//en-us/concept/203715
#
# id: 10000762
# url: https://store.playstation.com//en-us/concept/10000762
#
# id: 228868
# url: https://store.playstation.com//en-us/concept/228868
#
# id: 10005114
# url: https://store.playstation.com//en-us/concept/10005114
#
# id: 204861
# url: https://store.playstation.com//en-us/concept/204861
#
# id: 227319
# url: https://store.playstation.com//en-us/concept/227319
#
# id: 10006239
# url: https://store.playstation.com//en-us/concept/10006239
#
# id: 234567
# url: https://store.playstation.com//en-us/concept/234567
#
# id: 10005267
# url: https://store.playstation.com//en-us/concept/10005267
#
# id: 10000956
# url: https://store.playstation.com//en-us/concept/10000956
#
# id: 10000649
# url: https://store.playstation.com//en-us/concept/10000649
#
# id: 209441
# url: https://store.playstation.com//en-us/concept/209441
#
# id: 10004911
# url: https://store.playstation.com//en-us/concept/10004911
#
# id: 200763
# url: https://store.playstation.com//en-us/concept/200763
#
# id: 205342
# url: https://store.playstation.com//en-us/concept/205342
#
# id: 201061
# url: https://store.playstation.com//en-us/concept/201061
#
# id: 233072
# url: https://store.playstation.com//en-us/concept/233072
#
# id: 10000237
# url: https://store.playstation.com//en-us/concept/10000237
#
# id: 221694
# url: https://store.playstation.com//en-us/concept/221694
#
# id: 232248
# url: https://store.playstation.com//en-us/concept/232248
#
# id: 10001850
# url: https://store.playstation.com//en-us/concept/10001850
#
# id: 228857
# url: https://store.playstation.com//en-us/concept/228857
#
# id: 232796
# url: https://store.playstation.com//en-us/concept/232796
#
# id: 205366
# url: https://store.playstation.com//en-us/concept/205366
#
# id: 10003285
# url: https://store.playstation.com//en-us/concept/10003285
#
# id: 10004473
# url: https://store.playstation.com//en-us/concept/10004473
#
# id: 10001269
# url: https://store.playstation.com//en-us/concept/10001269
#
# id: 10005440
# url: https://store.playstation.com//en-us/concept/10005440
#
# id: 211297
# url: https://store.playstation.com//en-us/concept/211297

# %%
df = pd.DataFrame(data)
df
# Out:
#    concept_id                                                url  \
# 0      228748  https://store.playstation.com//en-us/concept/2...
# 1    10001130  https://store.playstation.com//en-us/concept/1...
# 2    10004836  https://store.playstation.com//en-us/concept/1...
# 3    10002100  https://store.playstation.com//en-us/concept/1...
# 4      231761  https://store.playstation.com//en-us/concept/2...
# 5    10002456  https://store.playstation.com//en-us/concept/1...
# 6      201930  https://store.playstation.com//en-us/concept/2...
# 13  https://image.api.playstation.com/gs2-sec/appk...
# 14  https://image.api.playstation.com/vulcan/ap/rn...
# 15  https://image.api.playstation.com/vulcan/ap/rn...
# 16  https://image.api.playstation.com/vulcan/ap/rn...
# 17  https://image.api.playstation.com/vulcan/ap/rn...
# 18  https://image.api.playstation.com/vulcan/ap/rn...
# 19  https://image.api.playstation.com/vulcan/ap/rn...
# 20  https://image.api.playstation.com/vulcan/ap/rn...
# 21  https://image.api.playstation.com/gs2-sec/appk...
# 22  https://image.api.playstation.com/vulcan/ap/rn...
# 23  https://image.api.playstation.com/gs2-sec/appk...
# 24  https://image.api.playstation.com/gs2-sec/appk...
# 25  https://image.api.playstation.com/vulcan/ap/rn...
# 26  https://image.api.playstation.com/vulcan/ap/rn...
# 27  https://image.api.playstation.com/vulcan/ap/rn...
# 28  https://image.api.playstation.com/vulcan/ap/rn...
# 29  https://image.api.playstation.com/vulcan/ap/rn...
# 30  https://image.api.playstation.com/gs2-sec/appk...
# 31  https://image.api.playstation.com/vulcan/ap/rn...
# 32  https://image.api.playstation.com/gs2-sec/appk...
# 33  https://image.api.playstation.com/vulcan/ap/rn...
# 34  https://image.api.playstation.com/vulcan/ap/rn...
# 35  https://image.api.playstation.com/vulcan/ap/rn...
# 36  https://image.api.playstation.com/vulcan/ap/rn...
# 37  https://image.api.playstation.com/gs2-sec/appk...
# 38  https://image.api.playstation.com/vulcan/ap/rn...
# 39  https://image.api.playstation.com/vulcan/ap/rn...
# 40  https://image.api.playstation.com/vulcan/img/r...
# 41  https://image.api.playstation.com/vulcan/ap/rn...
# 42  https://image.api.playstation.com/vulcan/ap/rn...
# 43  https://image.api.playstation.com/vulcan/ap/rn...
# 44  https://image.api.playstation.com/vulcan/ap/rn...
# 45  https://image.api.playstation.com/vulcan/ap/rn...
# 46  https://image.api.playstation.com/vulcan/ap/rn...
# 47  https://image.api.playstation.com/vulcan/ap/rn...
#
#                                                  name               rating  \
# 0                                            Fortnite            ESRB Teen
# 1   Call of Duty®: Modern Warfare® II - Cross-Gen ...      ESRB Mature 17+
# 2                                            NBA 2K23        ESRB Everyone
# 3                                   FINAL FANTASY XVI      ESRB Mature 17+
# 4                       Diablo® IV - Standard Edition      ESRB Mature 17+
# 5                               Marvel’s Spider-Man 2            ESRB Teen
# 6             Grand Theft Auto Online (PlayStation®5)          ESRB Mature
# 7                             EA SPORTS™ FIFA 23 PS5™        ESRB Everyone
# 8                              MLB® The Show™ 23 PS5™        ESRB Everyone
# 9                                  Apex Legends™ PS5™            ESRB Teen
# 10                                  Street Fighter™ 6            ESRB Teen
# 11                                     Genshin Impact            ESRB Teen
# 12                                 Madden NFL 23 PS5™        ESRB Everyone
# 13                                          Minecraft    ESRB Everyone 10+
# 14                                             F1® 23        ESRB Everyone
# 15                                       Overwatch® 2            ESRB Teen
# 16                              Destiny 2 PS4™ & PS5™            ESRB Teen
# 17                        Hogwarts Legacy PS5 Version            ESRB Teen
# 18     Tom Clancy's Rainbow Six® Siege Deluxe Edition      ESRB Mature 17+
# 19                                     Rocket League®        ESRB Everyone
# 20                     Marvel's Spider-Man Remastered            ESRB Teen
# 21                        theHunter: Call of the Wild            ESRB Teen
# 22                          STAR WARS Jedi: Survivor™            ESRB Teen
# 23                           The Elder Scrolls Online      ESRB Mature 17+
# 24                       Dead by Daylight PS4™ & PS5™          ESRB Mature
# 25  Madden NFL 24 Deluxe Edition PS5™ & PS4™ + Lim...        ESRB Everyone
# 26                                     Cyberpunk 2077          ESRB Mature
# 27                 WWE 2K23 Cross-Gen Digital Edition            ESRB Teen
# 28                                    Gran Turismo® 7        ESRB Everyone
# 29       Marvel's Spider-Man: Miles Morales PS4 & PS5            ESRB Teen
# 30                              Red Dead Redemption 2      ESRB Mature 17+
# 31                                    Mortal Kombat 1  ESRB Rating Pending
# 32  Call of Duty®: Black Ops III - Zombies Chronic...          ESRB Mature
# 33                                          Warframe®          ESRB Mature
# 34                                      Dead Island 2          ESRB Mature
# 35                               Rust Console Edition      ESRB Mature 17+
# 36                          Assassin's Creed Valhalla      ESRB Mature 17+
# 37                                          For Honor          ESRB Mature
# 38                                         Fallout 76          ESRB Mature
# 39                                God of War Ragnarök      ESRB Mature 17+
# 40                                        The Sims™ 4            ESRB Teen
# 41                         WORLD OF WARSHIPS: LEGENDS            ESRB Teen
# 42                                        War Thunder            ESRB Teen
# 43                         PGA 2K23 Cross-Gen Edition        ESRB Everyone
# 44                                    Resident Evil 4          ESRB Mature
# 45             Need for Speed™ Unbound Palace Edition            ESRB Teen
# 46                                 AEW: Fight Forever            ESRB Teen
# 47                                              SMITE            ESRB Teen
#
#                              notice0  \
# 0         In-game purchases optional
# 1   PS Plus required for online play
# 2   PS Plus required for online play
# 3                           1 player
# 4   PS Plus required for online play
# 5                           1 player
# 6   PS Plus required for online play
# 7   PS Plus required for online play
# 8   PS Plus required for online play
# 9         In-game purchases optional
# 10  PS Plus required for online play
# 11        In-game purchases optional
# 12  PS Plus required for online play
# 13  PS Plus required for online play
# 14  PS Plus required for online play
# 15        In-game purchases optional
# 16        In-game purchases optional
# 17        In-game purchases optional
# 18  PS Plus required for online play
# 19        In-game purchases optional
# 20                          1 player
# 21  PS Plus required for online play
# 22                          1 player
# 23  PS Plus required for online play
# 24  PS Plus required for online play
# 25  PS Plus required for online play
# 26                          1 player
# 27  PS Plus required for online play
# 28  PS Plus required for online play
# 29              Offline play enabled
# 30  PS Plus required for online play
# 31  PS Plus required for online play
# 32  PS Plus required for online play
# 33        In-game purchases optional
# 34  PS Plus required for online play
# 35  PS Plus required for online play
# 36        In-game purchases optional
# 37  PS Plus required for online play
# 38  PS Plus required for online play
# 39              Offline play enabled
# 40        In-game purchases optional
# 41        In-game purchases optional
# 42        In-game purchases optional
# 43  PS Plus required for online play
# 44              Offline play enabled
# 45  PS Plus required for online play
# 46  PS Plus required for online play
# 47        In-game purchases optional
#
#                                           notice1  \
# 0                            Online play required
# 1                      In-game purchases optional
# 2                      In-game purchases optional
# 3                           Remote Play supported
# 4                      In-game purchases optional
# 5                             Game Help supported
# 6                      In-game purchases optional
# 7                      In-game purchases optional
# 8                      In-game purchases optional
# 9                            Online play required
# 10                     In-game purchases optional
# 11                           Online play required
# 12                     In-game purchases optional
# 13                     In-game purchases optional
# 14                     In-game purchases optional
# 15                           Online play required
# 16                           Online play required
# 17                           Offline play enabled
# 18                     In-game purchases optional
# 19                           Online play optional
# 20                                           None
# 21   Supports up to 8 online players with PS Plus
# 22                                           None
# 23                     In-game purchases optional
# 24                     In-game purchases optional
# 25                     In-game purchases optional
# 26                          Remote Play supported
# 27                     In-game purchases optional
# 28                     In-game purchases optional
# 29                                       1 player
# 30                     In-game purchases optional
# 31                     In-game purchases optional
# 32                     In-game purchases optional
# 33                           Online play required
# 34   Supports up to 3 online players with PS Plus
# 35                     In-game purchases optional
# 36                           Online play optional
# 37                           Online play required
# 38                     In-game purchases optional
# 39                                       1 player
# 40                                       1 player
# 41                           Online play required
# 42                           Online play required
# 43                     In-game purchases optional
# 44                                       1 player
# 45  Supports up to 16 online players with PS Plus
# 46                     In-game purchases optional
# 47                           Online play required
#
#                                           notice2  \
# 0                               99 online players
# 1   Supports up to 99 online players with PS Plus
# 2   Supports up to 10 online players with PS Plus
# 3                                            None
# 4                            Online play required
# 5                                            None
# 6                            Online play required
# 7   Supports up to 22 online players with PS Plus
# 8    Supports up to 8 online players with PS Plus
# 9                               60 online players
# 10  Supports up to 16 online players with PS Plus
# 11                               4 online players
# 12   Supports up to 6 online players with PS Plus
# 13   Supports up to 8 online players with PS Plus
# 14  Supports up to 22 online players with PS Plus
# 15                              10 online players
# 16                              16 online players
# 17                                       1 player
# 18  Supports up to 10 online players with PS Plus
# 19                                  1 - 4 players
# 20                                           None
# 21                           Offline play enabled
# 22                                           None
# 23                           Online play required
# 24                           Online play required
# 25   Supports up to 6 online players with PS Plus
# 26                                           None
# 27   Supports up to 8 online players with PS Plus
# 28  Supports up to 20 online players with PS Plus
# 29                                           None
# 30  Supports up to 32 online players with PS Plus
# 31   Supports up to 8 online players with PS Plus
# 32  Supports up to 18 online players with PS Plus
# 33                               8 online players
# 34                           Online play optional
# 35                           Online play required
# 36                                       1 player
# 37   Supports up to 8 online players with PS Plus
# 38                           Online play required
# 39                          Remote Play supported
# 40                          Remote Play supported
# 41                              18 online players
# 42                              32 online players
# 43   Supports up to 4 online players with PS Plus
# 44                                           None
# 45                           Online play optional
# 46   Supports up to 4 online players with PS Plus
# 47                                       1 player
#
#                                           notice3                notice4  ...  \
# 0                                            None                   None  ...
# 1                            Online play optional          1 - 2 players  ...
# 2                            Online play optional          1 - 4 players  ...
# 3                                            None                   None  ...
# 4    Supports up to 4 online players with PS Plus          1 - 2 players  ...
# 5                                            None                   None  ...
# 6   Supports up to 30 online players with PS Plus  Remote Play supported  ...
# 7                            Online play optional          1 - 4 players  ...
# 8                            Online play optional          1 - 4 players  ...
# 9                                            None                   None  ...
# 10                           Online play optional          1 - 2 players  ...
# 11                                           None                   None  ...
# 12                           Online play optional          1 - 4 players  ...
# 13                           Online play optional          1 - 4 players  ...
# 14                           Online play optional          1 - 2 players  ...
# 15                                           None                   None  ...
# 16                                           None                   None  ...
# 17                          Remote Play supported                   None  ...
# 18                           Online play optional               1 player  ...
# 19                               8 online players  Remote Play supported  ...
# 20                                           None                   None  ...
# 21                                       1 player                   None  ...
# 22                                           None                   None  ...
# 23  Supports up to 99 online players with PS Plus                   None  ...
# 24   Supports up to 5 online players with PS Plus                   None  ...
# 25                           Online play optional          1 - 4 players  ...
# 26                                           None                   None  ...
# 27                           Online play optional          1 - 6 players  ...
# 28                           Online play optional          1 - 2 players  ...
# 29                                           None                   None  ...
# 30                           Online play optional               1 player  ...
# 31                           Online play optional          1 - 2 players  ...
# 32                           Online play optional          1 - 4 players  ...
# 33                          Remote Play supported                   None  ...
# 34                                       1 player  Remote Play supported  ...
# 35  Supports up to 99 online players with PS Plus  Remote Play supported  ...
# 36                                           None                   None  ...
# 37                          Remote Play supported                   None  ...
# 38  Supports up to 24 online players with PS Plus  Remote Play supported  ...
# 39                                           None                   None  ...
# 40                                           None                   None  ...
# 41                                           None                   None  ...
# 42                          Remote Play supported                   None  ...
# 43                           Online play optional          1 - 4 players  ...
# 44                                           None                   None  ...
# 45                                       1 player  Remote Play supported  ...
# 46                           Online play optional          1 - 4 players  ...
# 47                              10 online players  Remote Play supported  ...
#
#                                 c_name             c_rating  \
# 0                             Fortnite            ESRB_TEEN
# 1    Call of Duty®: Modern Warfare® II       ESRB_MATURE_17
# 2                             NBA 2K23        ESRB_EVERYONE
# 3                    FINAL FANTASY XVI       ESRB_MATURE_17
# 4                           Diablo® IV       ESRB_MATURE_17
# 5                Marvel's Spider-Man 2            ESRB_TEEN
# 6   Grand Theft Auto V (PlayStation®5)          ESRB_MATURE
# 7                   EA SPORTS™ FIFA 23        ESRB_EVERYONE
# 8                    MLB® The Show™ 23        ESRB_EVERYONE
# 9                        Apex Legends™            ESRB_TEEN
# 10                    Street Fighter 6            ESRB_TEEN
# 11                      Genshin Impact            ESRB_TEEN
# 12                  Madden NFL 23 PS5™        ESRB_EVERYONE
# 13                           Minecraft     ESRB_EVERYONE_10
# 14                              F1® 23        ESRB_EVERYONE
# 15             Overwatch® 2 - Season 5            ESRB_TEEN
# 16                           Destiny 2            ESRB_TEEN
# 17                     Hogwarts Legacy            ESRB_TEEN
# 18     Tom Clancy's Rainbow Six® Siege       ESRB_MATURE_17
# 19                      Rocket League®        ESRB_EVERYONE
# 20                 Marvel's Spider-Man            ESRB_TEEN
# 21         theHunter: Call of the Wild            ESRB_TEEN
# 22           STAR WARS Jedi: Survivor™            ESRB_TEEN
# 23            The Elder Scrolls Online       ESRB_MATURE_17
# 24                    Dead by Daylight          ESRB_MATURE
# 25                       Madden NFL 24        ESRB_EVERYONE
# 26                      Cyberpunk 2077          ESRB_MATURE
# 27                            WWE 2K23            ESRB_TEEN
# 28                     Gran Turismo® 7        ESRB_EVERYONE
# 29  Marvel's Spider-Man: Miles Morales            ESRB_TEEN
# 30               Red Dead Redemption 2       ESRB_MATURE_17
# 31                     Mortal Kombat 1  ESRB_RATING_PENDING
# 32        Call of Duty®: Black Ops III          ESRB_MATURE
# 33                            Warframe          ESRB_MATURE
# 34                       Dead Island 2          ESRB_MATURE
# 35                Rust Console Edition       ESRB_MATURE_17
# 36           Assassin's Creed Valhalla       ESRB_MATURE_17
# 37                           For Honor          ESRB_MATURE
# 38                          Fallout 76          ESRB_MATURE
# 39                 God of War Ragnarök       ESRB_MATURE_17
# 40                         The Sims™ 4            ESRB_TEEN
# 41          World of Warships: Legends            ESRB_TEEN
# 42                         War Thunder            ESRB_TEEN
# 43                       PGA TOUR 2K23        ESRB_EVERYONE
# 44                     Resident Evil 4          ESRB_MATURE
# 45             Need for Speed™ Unbound            ESRB_TEEN
# 46                  AEW: Fight Forever            ESRB_TEEN
# 47                               SMITE            ESRB_TEEN
#
#                                     c_id  \
# 0   UP1477-PPSA01922_00-FORTNITETESTING2
# 1   UP0002-PPSA01649_00-CODMW2CROSSGEN01
# 2   UP1001-PPSA07169_00-NBA2K23CROSSBUY0
# 3   UP0082-PPSA10664_00-FF16SIEA00000002
# 4   UP0002-PPSA02442_00-DIVGAMESTANDARD1
# 5   UP9000-PPSA03016_00-MARVELSPIDERMAN2
# 6   UP1004-PPSA03420_00-GTAOSTANDALONE01
# 7   UP0006-PPSA06279_00-FIFAFOOTBALL2023
# 8   UP9000-PPSA09243_00-MLBTHESHOW23SHIP
# 9   UP0006-PPSA04873_00-APEXLEGENDRSPWN1
# 10  UP0102-PPSA02632_00-SF600000STANDARD
# 11  UP6262-PPSA02562_00-OSRELSIEAGENSHIN
# 12  UP0006-PPSA05481_00-MADDENNFL23GAME1
# 13  UP4433-CUSA00744_00-MINECRAFTPS40001
# 14  UP0006-PPSA09801_00-F12023PS5GAME000
# 15  UP0002-PPSA07805_00-OWORIGINS0000000
# 16  UP0002-PPSA02409_00-DESTINYTHEGAME02
# 17  UP1018-PPSA01593_00-HOGWARTSLEGACY01
# 18  UP0001-PPSA01396_00-RB6SIEGEDELUXE08
# 19  UP2002-CUSA01163_00-ROCKETLEAGUENA01
# 20  UP9000-PPSA01467_00-MARVELSSPIDERMAN
# 21  UP3501-CUSA08661_00-THCOTWBASE000000
# 22  UP0006-PPSA07783_00-APPLEJACKGAME000
# 23  UP1003-PPSA02017_00-ESOMORROWINDBUND
# 24  UP3509-PPSA02048_00-DEADBYDAYLIGHT00
# 25  UP0006-PPSA10508_00-DELUXEEDITIONM24
# 26  UP4497-PPSA03974_00-0000000000000CP1
# 27  UP1001-PPSA08105_00-WWE2K23PS4PS5CGE
# 28  UP9000-PPSA01317_00-GT7STD0000000PS5
# 29  UP9000-PPSA01411_00-MARVELSSMMORALES
# 30  UP1004-CUSA03041_00-REDEMPTIONFULL02
# 31  UP1018-PPSA07570_00-MKONE00000000000
# 32  UP0002-CUSA02290_00-CODBO3ZOMBIESEDN
# 33  UP2097-PPSA01737_00-WARFRAMEPS500000
# 34  UP2047-PPSA03098_00-DI2MAINSIEAPS500
# 35  UP4415-CUSA14296_00-D11PROJECTRUST01
# 36  UP0001-PPSA01491_00-GAME000000000000
# 37  UP0001-CUSA05218_00-FHGAMEPS40000001
# 38  UP1003-CUSA12057_00-PRJMTN0000000000
# 39  UP9000-PPSA08329_00-GOWRAGNAROK00000
# 40  UP0006-CUSA09209_00-THESIMS400000000
# 41  UP0680-PPSA02219_00-8502330301011232
# 42  UP4432-PPSA01950_00-2173548409910606
# 43  UP1001-PPSA04390_00-PGATOUR2K23CRSGN
# 44  UP0102-PPSA07411_00-RE4RMAINGAME0000
# 45  UP0006-PPSA01716_00-DELUXEEDITION000
# 46  UP4389-PPSA09351_00-AEWRESTLINGPS5US
# 47  UP0334-CUSA02328_00-SMITEXXXXXXXXXXX
#
#                                     c_genres  \
# 0                [Action, Adventure, Unique]
# 1                                   [Action]
# 2                                    [Sport]
# 3               [Action, Role Playing Games]
# 4                                   [Unique]
# 5                                   [Action]
# 6                        [Action, Adventure]
# 7                                    [Sport]
# 8                                    [Sport]
# 9                          [Action, Shooter]
# 10                                [Fighting]
# 11   [Action, Adventure, Role Playing Games]
# 12                                   [Sport]
# 13                               [Adventure]
# 14                          [Driving/Racing]
# 15                [Shooter, Action, Shooter]
# 16              [Adventure, Shooter, Action]
# 17                                  [Unique]
# 18                         [Action, Shooter]
# 19           [Sport, Action, Driving/Racing]
# 20                                  [Action]
# 21                          [Shooter, Sport]
# 22                                  [Action]
# 23  [Role Playing Games, Role Playing Games]
# 24                  [Horror, Action, Horror]
# 25                                   [Sport]
# 26                                  [Unique]
# 27                                  [Action]
# 28                          [Driving/Racing]
# 29                                  [Action]
# 30               [Action, Adventure, Unique]
# 31                                [Fighting]
# 32                [Action, Shooter, Shooter]
# 33                 [Action, Shooter, Unique]
# 34                          [Action, Action]
# 35              [Action, Adventure, Shooter]
# 36                      [Role Playing Games]
# 37                          [Action, Action]
# 38                      [Role Playing Games]
# 39                                  [Action]
# 40                      [Action, Simulation]
# 41                 [Action, Action, Shooter]
# 42              [Simulation, Action, Unique]
# 43                                   [Sport]
# 44               [Action, Adventure, Horror]
# 45                          [Driving/Racing]
# 46                                [Fighting]
# 47               [Action, Shooter, Strategy]
#
#                                   c_default_prod_name c_np_title_id  \
# 0                                            Fortnite  PPSA01922_00
# 1   Call of Duty®: Modern Warfare® II - Cross-Gen ...  PPSA01649_00
# 2                                            NBA 2K23  PPSA07169_00
# 3                                   FINAL FANTASY XVI  PPSA10664_00
# 4                       Diablo® IV - Standard Edition  PPSA02442_00
# 43  UP1001-PPSA04390_00-PGATOUR2K23CRSGN-U002          $69.99    6999
# 44  UP0102-PPSA07411_00-RE4RMAINGAME0000-U003          $59.99    5999
# 45  UP0006-PPSA01716_00-DELUXEEDITION000-U001          $79.99    7999
# 46  UP4389-PPSA09351_00-AEWRESTLINGPS5US-U001          $59.99    5999
# 47  UP0334-CUSA02328_00-SMITEXXXXXXXXXXX-U099            Free       0
#
#    c_discounted_price
# 0                Free
# 1              $69.99
# 2                None
# 3              $69.99
# 4              $69.99
# 5              $69.99
# 6              $19.99
# 7              $17.49
# 8              $69.99
# 9                Free
# 10             $59.99
# 11               Free
# 12             $69.99
# 13             $19.99
# 14             $69.99
# 15               Free
# 16               Free
# 17             $69.99
# 18             $39.99
# 19               Free
# 20             $49.99
# 21             $29.99
# 22             $69.99
# 23             $19.99
# 24             $22.49
# 25             $99.99
# 26             $24.99
# 27             $69.99
# 28             $69.99
# 29             $49.99
# 30             $59.99
# 31             $69.99
# 32             $19.79
# 33               Free
# 34             $69.99
# 35             $49.99
# 36             $37.79
# 37             $17.39
# 38             $39.99
# 39             $69.99
# 40               Free
# 41               Free
# 42               Free
# 43             $69.99
# 44             $59.99
# 45             $79.99
# 46             $59.99
# 47               Free
#
# [48 rows x 28 columns]

# %%
concept_id = 204861
hash = '16b0b76dac848b6e33ed088a5a3aedb738e51c9481c6a6eb6d6c1c1991ea1f39'

test = f'https://web.np.playstation.com/api/graphql/v1//op?operationName=queryRetrieveTelemetryDataPDPConcept&variables={{"conceptId":"{concept_id}","productId":null}}&extensions={{"persistedQuery":{{"version":1,"sha256Hash":"{hash}"}}}}'

headers={"X-Psn-Store-Locale-Override":"en-US"}

response = session.get(test, headers=headers)

# %%
d = {}

j = json.loads(response.text)
product = j['data']['conceptRetrieve']['defaultProduct']

d['c_name'] = j['data']['conceptRetrieve']['name']
d['c_rating'] = product['contentRating']['name']
d['c_id'] = product['id']
d['c_genres'] = list(map(lambda a: a['value'], product['localizedGenres']))
d['c_default_prod_name'] = product['name']
d['c_np_title_id'] = product['npTitleId']
d['c_sku_id'] = product['skus'][0]['id']
d['c_display_price'] = product['skus'][0]['displayPrice']
d['c_price'] = product['skus'][0]['price']

main_cta = list(filter(lambda a: a['price']['serviceBranding'][0] == 'NONE', product['webctas']))
if len(main_cta) > 0:
    d['c_discounted_price'] = main_cta[0]['price']['discountedPrice']
else:
    d['c_discounted_price'] = None

d
# Out:
# {'c_name': 'DRAGON BALL XENOVERSE 2',
#  'c_rating': 'ESRB_TEEN',
#  'c_id': 'UP0700-CUSA05350_00-DRAGONBALLXV2002',
#  'c_genres': ['Action', 'Casual', 'Fighting'],
#  'c_default_prod_name': 'DRAGON BALL XENOVERSE 2',
#  'c_np_title_id': 'CUSA05350_00',
#  'c_sku_id': 'UP0700-CUSA05350_00-DRAGONBALLXV2002-U001',
#  'c_display_price': '$59.99',
#  'c_price': 5999,
#  'c_discounted_price': '$8.99'}
